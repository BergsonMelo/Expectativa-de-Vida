# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df_dados = pd.read_csv("Life Expectancy Data.csv")

# %%
df_dados_numericos = df_dados[["Life expectancy ", "infant deaths", "Alcohol", "percentage expenditure", "GDP", "Hepatitis B",
                     " BMI ", "under-five deaths ", "Polio", "Total expenditure", "Diphtheria ", " HIV/AIDS",
                     " thinness  1-19 years", " thinness 5-9 years", "Income composition of resources",
                     "Schooling"]]

# %%
df_dados_numericos
# Out:
#       Life expectancy   infant deaths  Alcohol  percentage expenditure  \
# 0                 65.0             62     0.01               71.279624
# 1                 59.9             64     0.01               73.523582
# 2                 59.9             66     0.01               73.219243
# 3                 59.5             69     0.01               78.184215
# 4                 59.2             71     0.01                7.097109
# ...                ...            ...      ...                     ...
# 2933              44.3             27     4.36                0.000000
# 2934              44.5             26     4.06                0.000000
# 2935              44.8             25     4.43                0.000000
# 2936              45.3             25     1.72                0.000000
# 2937              46.0             24     1.68                0.000000
#
#              GDP  Hepatitis B   BMI   under-five deaths   Polio  \
# ...

# %% [markdown]
# # Gráficos de Dispersão

# %%
sns.scatterplot(data = df_dados_numericos, x = "Alcohol", y = "Life expectancy ")
# Out:
# <AxesSubplot:xlabel='Alcohol', ylabel='Life expectancy '>

# %%
sns.scatterplot(data = df_dados_numericos, x = "Alcohol", y = "Income composition of resources") # Tirar os valores do ICR = 0.
# Out:
# <AxesSubplot:xlabel='Alcohol', ylabel='Income composition of resources'>

# %%
sns.scatterplot(data = df_dados_numericos, x = "Life expectancy ", y = "Income composition of resources")
# Out:
# <AxesSubplot:xlabel='Life expectancy ', ylabel='Income composition of resources'>

# %%
sns.scatterplot(data = df_dados_numericos, x = "Schooling", y = "Life expectancy ") # Tirar a escolaridade = 0.
# Out:
# <AxesSubplot:xlabel='Schooling', ylabel='Life expectancy '>

# %%
sns.scatterplot(data = df_dados_numericos, x = "Schooling", y = "Income composition of resources")
# Out:
# <AxesSubplot:xlabel='Schooling', ylabel='Income composition of resources'>

# %%
sns.scatterplot(data = df_dados_numericos, x = " BMI ", y = "infant deaths") # Não deve ter números acima de 1000.
# Out:
# <AxesSubplot:xlabel=' BMI ', ylabel='infant deaths'>

# %%
sns.scatterplot(data = df_dados_numericos, x = " BMI ", y = "under-five deaths ") # Não deve ter números acima de 1000.
# Out:
# <AxesSubplot:xlabel=' BMI ', ylabel='under-five deaths '>

# %%
sns.scatterplot(data = df_dados_numericos, x = "Total expenditure", y = "GDP") # Tirar GDP = 0 e gastos = 0.
# Out:
# <AxesSubplot:xlabel='Total expenditure', ylabel='GDP'>
