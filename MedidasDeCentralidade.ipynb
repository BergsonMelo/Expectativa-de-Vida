# %%
import pandas as pd
import numpy as np

# %%
df_dados = pd.read_csv("Life Expectancy Data.csv")

# %%
colunas_selecionadas = ["Country", "Year", "Status", "Life expectancy ", "infant deaths", "Alcohol", "percentage expenditure", "GDP", "Hepatitis B",
                     " BMI ", "under-five deaths ", "Polio", "Total expenditure", "Diphtheria ", " HIV/AIDS",
                     " thinness  1-19 years", " thinness 5-9 years", "Income composition of resources",
                     "Schooling"]
df_dados = df_dados[colunas_selecionadas]

# %%
df_dados
# Out:
#           Country  Year      Status  Life expectancy   infant deaths  Alcohol  \
# 0     Afghanistan  2015  Developing              65.0             62     0.01
# 1     Afghanistan  2014  Developing              59.9             64     0.01
# 2     Afghanistan  2013  Developing              59.9             66     0.01
# 3     Afghanistan  2012  Developing              59.5             69     0.01
# 4     Afghanistan  2011  Developing              59.2             71     0.01
# ...           ...   ...         ...               ...            ...      ...
# 2933     Zimbabwe  2004  Developing              44.3             27     4.36
# 2934     Zimbabwe  2003  Developing              44.5             26     4.06
# 2935     Zimbabwe  2002  Developing              44.8             25     4.43
# 2936     Zimbabwe  2001  Developing              45.3             25     1.72
# 2937     Zimbabwe  2000  Developing              46.0             24     1.68
#
#       percentage expenditure         GDP  Hepatitis B   BMI   \
# 0                  71.279624  584.259210         65.0   19.1
# 1                  73.523582  612.696514         62.0   18.6
# 2                  73.219243  631.744976         64.0   18.1
# 3                  78.184215  669.959000         67.0   17.6
# 4                   7.097109   63.537231         68.0   17.2
# ...                      ...         ...          ...    ...
# 2933                0.000000  454.366654         68.0   27.1
# 2934                0.000000  453.351155          7.0   26.7
# 2935                0.000000   57.348340         73.0   26.3
# 2936                0.000000  548.587312         76.0   25.9
# 2937                0.000000  547.358878         79.0   25.5
#
#       under-five deaths   Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# 0                     83    6.0               8.16         65.0        0.1
# 1                     86   58.0               8.18         62.0        0.1
# 2                     89   62.0               8.13         64.0        0.1
# 3                     93   67.0               8.52         67.0        0.1
# 4                     97   68.0               7.87         68.0        0.1
# ...                  ...    ...                ...          ...        ...
# 2933                  42   67.0               7.13         65.0       33.6
# 2934                  41    7.0               6.52         68.0       36.7
# 2935                  40   73.0               6.53         71.0       39.8
# 2936                  39   76.0               6.16         75.0       42.1
# 2937                  39   78.0               7.10         78.0       43.5
#
#        thinness  1-19 years   thinness 5-9 years  \
# 0                      17.2                 17.3
# 1                      17.5                 17.5
# 2                      17.7                 17.7
# 3                      17.9                 18.0
# 4                      18.2                 18.2
# ...                     ...                  ...
# 2933                    9.4                  9.4
# 2934                    9.8                  9.9
# 2935                    1.2                  1.3
# 2936                    1.6                  1.7
# 2937                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 19 columns]

# %%
def central(dfcoluna):
    media = dfcoluna.mean()
    mediana = dfcoluna.median()
    moda = dfcoluna.mode().squeeze() 
    
    return {"Média": media, "Mediana" : mediana, "Moda" : moda}

# %%
def dispersao(dfcoluna):
    variancia = np.var(dfcoluna)
    desvio_p = np.std(dfcoluna) 
    return {"Variância": variancia, "Desvio Padrão" : desvio_p}

# %%
df_dadosC = df_dados[["Life expectancy ", "infant deaths", "Alcohol", "percentage expenditure", "GDP", "Hepatitis B",
                     " BMI ", "under-five deaths ", "Polio", "Total expenditure", "Diphtheria ", " HIV/AIDS",
                     " thinness  1-19 years", " thinness 5-9 years", "Income composition of resources",
                     "Schooling"]]

# %%
df_dadosC
# Out:
#       Life expectancy   infant deaths  Alcohol  percentage expenditure  \
# 0                 65.0             62     0.01               71.279624
# 1                 59.9             64     0.01               73.523582
# 2                 59.9             66     0.01               73.219243
# 3                 59.5             69     0.01               78.184215
# 4                 59.2             71     0.01                7.097109
# ...                ...            ...      ...                     ...
# 2933              44.3             27     4.36                0.000000
# 2934              44.5             26     4.06                0.000000
# 2935              44.8             25     4.43                0.000000
# 2936              45.3             25     1.72                0.000000
# 2937              46.0             24     1.68                0.000000
#
#              GDP  Hepatitis B   BMI   under-five deaths   Polio  \
# 0     584.259210         65.0   19.1                  83    6.0
# 1     612.696514         62.0   18.6                  86   58.0
# 2     631.744976         64.0   18.1                  89   62.0
# 3     669.959000         67.0   17.6                  93   67.0
# 4      63.537231         68.0   17.2                  97   68.0
# ...          ...          ...    ...                 ...    ...
# 2933  454.366654         68.0   27.1                  42   67.0
# 2934  453.351155          7.0   26.7                  41    7.0
# 2935   57.348340         73.0   26.3                  40   73.0
# 2936  548.587312         76.0   25.9                  39   76.0
# 2937  547.358878         79.0   25.5                  39   78.0
#
#       Total expenditure  Diphtheria    HIV/AIDS   thinness  1-19 years  \
# 0                  8.16         65.0        0.1                   17.2
# 1                  8.18         62.0        0.1                   17.5
# 2                  8.13         64.0        0.1                   17.7
# 3                  8.52         67.0        0.1                   17.9
# 4                  7.87         68.0        0.1                   18.2
# ...                 ...          ...        ...                    ...
# 2933               7.13         65.0       33.6                    9.4
# 2934               6.52         68.0       36.7                    9.8
# 2935               6.53         71.0       39.8                    1.2
# 2936               6.16         75.0       42.1                    1.6
# 2937               7.10         78.0       43.5                   11.0
#
#        thinness 5-9 years  Income composition of resources  Schooling
# 0                    17.3                            0.479       10.1
# 1                    17.5                            0.476       10.0
# 2                    17.7                            0.470        9.9
# 3                    18.0                            0.463        9.8
# 4                    18.2                            0.454        9.5
# ...                   ...                              ...        ...
# 2933                  9.4                            0.407        9.2
# 2934                  9.9                            0.418        9.5
# 2935                  1.3                            0.427       10.0
# 2936                  1.7                            0.427        9.8
# 2937                 11.2                            0.434        9.8
#
# [2938 rows x 16 columns]

# %%
centralidade_das_variaveis = {}

# %%
for coluna in df_dadosC.drop(["GDP"], axis = 1):   
    dado = df_dadosC[coluna]
    centralidade_das_variaveis[coluna] = central(dado)

# %%
GDP = df_dadosC["GDP"]
media_gdp = GDP.mean()
mediana_gdp = GDP.median()
centralidade_das_variaveis["GDP"] = {"Média" : media_gdp, "Mediana" : mediana_gdp}

# %%
centralidade_das_variaveis
# Out:
# {'Life expectancy ': {'Média': 69.22493169398912,
#   'Mediana': 72.1,
#   'Moda': 73.0},
#  'infant deaths': {'Média': 30.303948264125257, 'Mediana': 3.0, 'Moda': 0},
#  'Alcohol': {'Média': 4.6028607871720375, 'Mediana': 3.755, 'Moda': 0.01},
#  'percentage expenditure': {'Média': 738.2512954533823,
#   'Mediana': 64.912906045,
#   'Moda': 0.0},
#  'Hepatitis B': {'Média': 80.94046121593291, 'Mediana': 92.0, 'Moda': 99.0},
#  ' BMI ': {'Média': 38.32124655647373, 'Mediana': 43.5, 'Moda': 58.5},
#  'under-five deaths ': {'Média': 42.0357385976855, 'Mediana': 4.0, 'Moda': 0},
#  'Polio': {'Média': 82.55018842069202, 'Mediana': 93.0, 'Moda': 99.0},
#  'Total expenditure': {'Média': 5.9381895280235915,
#   'Mediana': 5.755,
#   'Moda': 4.6},
#  'Diphtheria ': {'Média': 82.32408359027065, 'Mediana': 93.0, 'Moda': 99.0},
#  ' HIV/AIDS': {'Média': 1.7421034717494939, 'Mediana': 0.1, 'Moda': 0.1},
#  ' thinness  1-19 years': {'Média': 4.8397038567493205,
#   'Mediana': 3.3,
#   'Moda': 1.0},
#  ' thinness 5-9 years': {'Média': 4.870316804407711,
#   'Mediana': 3.3,
#   'Moda': 0.9},
#  'Income composition of resources': {'Média': 0.6275510645976166,
#   'Mediana': 0.677,
#   'Moda': 0.0},
#  'Schooling': {'Média': 11.992792792792786, 'Mediana': 12.3, 'Moda': 12.9},
#  'GDP': {'Média': 7483.158469138481, 'Mediana': 1766.947595}}

# %%
dispersao_das_variaveis = {}

# %%
for colunas in df_dadosC:
    dados2 = df_dadosC[colunas]
    dispersao_das_variaveis[colunas] = dispersao(dados2)

# %%
dispersao_das_variaveis
# Out:
# {'Life expectancy ': {'Variância': 90.67307376582568,
#   'Desvio Padrão': 9.522241005447492},
#  'infant deaths': {'Variância': 13901.926335670341,
#   'Desvio Padrão': 117.90643042544517},
#  'Alcohol': {'Variância': 16.416063645342746,
#   'Desvio Padrão': 4.051674178082777},
#  'percentage expenditure': {'Variância': 3950460.4161855783,
#   'Desvio Padrão': 1987.5765183221447},
#  'GDP': {'Variância': 203555950.81344026, 'Desvio Padrão': 14267.303557906107},
#  'Hepatitis B': {'Variância': 628.2421574392729,
#   'Desvio Padrão': 25.06475927351533},
#  ' BMI ': {'Variância': 401.6249308152427,
#   'Desvio Padrão': 20.040582097714694},
#  'under-five deaths ': {'Variância': 25734.011997089085,
#   'Desvio Padrão': 160.4182408490041},
#  'Polio': {'Variância': 548.6853022940603,
#   'Desvio Padrão': 23.424032579683207},
#  'Total expenditure': {'Variância': 6.239299708916882,
#   'Desvio Padrão': 2.497859025028611},
#  'Diphtheria ': {'Variância': 562.2992178566609,
#   'Desvio Padrão': 23.712849214226893},
#  ' HIV/AIDS': {'Variância': 25.77511974150574,
#   'Desvio Padrão': 5.0769203008818},
#  ' thinness  1-19 years': {'Variância': 19.531395366844496,
#   'Desvio Padrão': 4.419433828766361},
#  ' thinness 5-9 years': {'Variância': 20.323016979524773,
#   'Desvio Padrão': 4.508105697465929},
#  'Income composition of resources': {'Variância': 0.04446425749706239,
#   'Desvio Padrão': 0.2108654962222658},
#  'Schooling': {'Variância': 11.278275984092264,
#   'Desvio Padrão': 3.3583144558084883}}
